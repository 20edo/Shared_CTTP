# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pandas as pd
from math import *

# %%
# Import data and clear unusefull columns
simple100 = pd.read_csv('Report_Data/simple_U-y100_2000.csv')
simple100 = simple100.drop(columns=['epsilon','vtkValidPointMask','nut','arc_length','Points:1','Points:2','yPlus','Time','k','p'])
simple100
# Out:
#            U:0       U:1  U:2  Points:0
# 0     0.005447  12.24368  0.0  -0.12000
# 1     0.005910  12.72770  0.0  -0.11976
# 2     0.006372  13.21174  0.0  -0.11952
# 3     0.006661  13.73118  0.0  -0.11928
# 4     0.006299  14.38330  0.0  -0.11904
# ...        ...       ...  ...       ...
# 996  -0.005836  13.92258  0.0   0.11904
# 997  -0.005877  13.27869  0.0   0.11928
# 998  -0.005424  12.76780  0.0   0.11952
# 999  -0.004838  12.29256  0.0   0.11976
# 1000 -0.004252  11.81733  0.0   0.12000
#
# [1001 rows x 4 columns]

# %%
# Convert to numpy array
simple100np = simple100.to_numpy();
simple100.append(np.sqrt(np.multiply(simple100np[:,0:3],simple100np[:,0:3])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-92e120ac6f65> in <module>
#       1 # Convert to numpy array
#       2 simple100np = simple100.to_numpy();
# ----> 3 simple100.append(np.sqrt(np.multiply(simple100np[:,0:3],simple100np[:,0:3])))
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7132         else:
#    7133             to_concat = [self, other]
# -> 7134         return concat(
#    7135             to_concat,
#    7136             ignore_index=ignore_index,
#
# /usr/lib/python3/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     242     ValueError: Indexes have overlapping values: ['a']
#     243     """
# --> 244     op = _Concatenator(
#     245         objs,
#     246         axis=axis,
#
# /usr/lib/python3/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     330                     " only Series and DataFrame objs are valid".format(type(obj))
#     331                 )
# --> 332                 raise TypeError(msg)
#     333
#     334             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid

# %%
# Plot
ax = plt.plot(simple100np[:,3],simple100np[:,0:3])

ax.legend('Ux','Uy','Uz')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-de1de8ca2853> in <module>
#       2 ax = plt.plot(simple100np[:,3],simple100np[:,0:3])
#       3
# ----> 4 ax.legend('Ux','Uy','Uz')
#
# AttributeError: 'list' object has no attribute 'legend'
