# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pandas as pd
from math import *

# %%
# Import data and clear unusefull columns
simple100 = pd.read_csv('Report_Data/simple_U-y100_2000.csv')
simple100 = simple100.drop(columns=['epsilon','vtkValidPointMask','nut','arc_length','Points:1','Points:2','yPlus','Time','k','p'])
simple100
# Out:
#            U:0       U:1  U:2  Points:0
# 0     0.005447  12.24368  0.0  -0.12000
# 1     0.005910  12.72770  0.0  -0.11976
# 2     0.006372  13.21174  0.0  -0.11952
# 3     0.006661  13.73118  0.0  -0.11928
# 4     0.006299  14.38330  0.0  -0.11904
# ...        ...       ...  ...       ...
# 996  -0.005836  13.92258  0.0   0.11904
# 997  -0.005877  13.27869  0.0   0.11928
# 998  -0.005424  12.76780  0.0   0.11952
# 999  -0.004838  12.29256  0.0   0.11976
# 1000 -0.004252  11.81733  0.0   0.12000
#
# [1001 rows x 4 columns]

# %%
# Convert to numpy array
simple100np = simple100.to_numpy();
simple100np = np.array(simple100np,np.sqrt(np.dot(simple100np[:,0:3],np.transpose(simple100np[:,0:3]))))
# Out:
# <ipython-input-10-c06603b14500>:3: RuntimeWarning: invalid value encountered in sqrt
#   simple100np = np.array(simple100np,np.sqrt(np.dot(simple100np[:,0:3],np.transpose(simple100np[:,0:3]))))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c06603b14500> in <module>
#       1 # Convert to numpy array
#       2 simple100np = simple100.to_numpy();
# ----> 3 simple100np = np.array(simple100np,np.sqrt(np.dot(simple100np[:,0:3],np.transpose(simple100np[:,0:3]))))
#
# TypeError: data type not understood

# %%
# Plot
ax = plt.plot(simple100np[:,3],simple100np[:,0:3])

ax.legend('Ux','Uy','Uz')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-de1de8ca2853> in <module>
#       2 ax = plt.plot(simple100np[:,3],simple100np[:,0:3])
#       3
# ----> 4 ax.legend('Ux','Uy','Uz')
#
# AttributeError: 'list' object has no attribute 'legend'

# %%
np.sqrt(np.multiply(simple100np[:,0:3],simple100np[:,0:3]))
# Out:
# array([[5.447359e-03, 1.224368e+01, 0.000000e+00],
#        [5.909684e-03, 1.272770e+01, 0.000000e+00],
#        [6.372023e-03, 1.321174e+01, 0.000000e+00],
#        ...,
#        [5.423915e-03, 1.276780e+01, 0.000000e+00],
#        [4.837834e-03, 1.229256e+01, 0.000000e+00],
#        [4.251771e-03, 1.181733e+01, 0.000000e+00]])

# %%
A=(np.dot(simple100np[:,0:3],np.transpose(simple100np[:,0:3])))

# %%
plt.plot(A)
plt.show()

# %%
A
# Out:
# array([[ 2.95970467e+03, -3.82455698e+03, -3.13521924e-16],
#        [-3.82455698e+03,  1.86050465e+05,  1.74483406e-16],
#        [-3.13521924e-16,  1.74483406e-16,  7.21975004e-34]])
